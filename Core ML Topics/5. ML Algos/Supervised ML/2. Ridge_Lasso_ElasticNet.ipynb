# %%
'''
Ridge Regression:
Definition: 
Ridge regression is a type of linear regression that includes a regularization term to 
prevent overfitting by penalizing large coefficients. 
It is particularly useful when dealing with multicollinearity or when the number of 
predictors exceeds the number of observations.]
Formula:
Ridge Regression Loss Function (theta):
L(theta) = ||y - X * theta||^2 + lambda * ||theta||^2

Where:
- L(theta) is the loss function.
- y is the target variable.
- X is the feature matrix.
- theta is the vector of coefficients.
- lambda is the regularization parameter that controls the strength of the penalty.


'''
# Out:
# '\nRidge Regression:\nDefinition: \nRidge regression is a type of linear regression that includes a regularization term to \nprevent overfitting by penalizing large coefficients. \nIt is particularly useful when dealing with multicollinearity or when the number of \npredictors exceeds the number of observations.]\nFormula:\nRidge Regression Loss Function (theta):\nL(theta) = ||y - X * theta||^2 + lambda * ||theta||^2\n\nWhere:\n- L(theta) is the loss function.\n- y is the target variable.\n- X is the feature matrix.\n- theta is the vector of coefficients.\n- lambda is the regularization parameter that controls the strength of the penalty.\n\n\n'

# %%
'''
lasso Regression:
Definition:
Lasso regression is a type of linear regression that includes a regularization term to
prevent overfitting by penalizing the absolute values of the coefficients.
It is particularly useful for feature selection, as it can shrink some coefficients to zero.
Formula:
Lasso Regression Loss Function (theta symbol θ):
L(θ) = ||y - X * θ||^2 + λ * ||θ||_1
Where:
- L(θ) is the loss function.
- y is the target variable.
- X is the feature matrix.
- θ is the vector of coefficients.
- λ (lambda) is the regularization parameter that controls the strength of the penalty.
'''
# Out:
# '\nlasso Regression:\nDefinition:\nLasso regression is a type of linear regression that includes a regularization term to\nprevent overfitting by penalizing the absolute values of the coefficients.\nIt is particularly useful for feature selection, as it can shrink some coefficients to zero.\nFormula:\nLasso Regression Loss Function (theta symbol θ):\nL(θ) = ||y - X * θ||^2 + λ * ||θ||_1\nWhere:\n- L(θ) is the loss function.\n- y is the target variable.\n- X is the feature matrix.\n- θ is the vector of coefficients.\n- λ (lambda) is the regularization parameter that controls the strength of the penalty.\n'

# %%
'''
ElasticNet Regression:
Definition:
ElasticNet regression is a type of linear regression that combines both Lasso and Ridge
regression techniques. It includes both L1 (Lasso) and L2 (Ridge) regularization terms
to prevent overfitting and handle multicollinearity.
Formula:
ElasticNet Regression Loss Function (theta symbol θ):
L(θ) = ||y - X * θ||^2 + λ1 * ||θ||_1 + λ2 * ||θ||_2^2

Where:
- L(θ) is the loss function.
- y is the target variable.
- X is the feature matrix.
- θ is the vector of coefficients.
- λ1 (lambda1) is the regularization parameter for Lasso (L1 penalty).
- λ2 (lambda2) is the regularization parameter for Ridge (L2 penalty).
'''
# Out:
# '\nElasticNet Regression:\nDefinition:\nElasticNet regression is a type of linear regression that combines both Lasso and Ridge\nregression techniques. It includes both L1 (Lasso) and L2 (Ridge) regularization terms\nto prevent overfitting and handle multicollinearity.\nFormula:\nElasticNet Regression Loss Function (theta symbol θ):\nL(θ) = ||y - X * θ||^2 + λ1 * ||θ||_1 + λ2 * ||θ||_2^2\n\nWhere:\n- L(θ) is the loss function.\n- y is the target variable.\n- X is the feature matrix.\n- θ is the vector of coefficients.\n- λ1 (lambda1) is the regularization parameter for Lasso (L1 penalty).\n- λ2 (lambda2) is the regularization parameter for Ridge (L2 penalty).\n'

# %%
'''
Cross Validation:
Cross-validation is a technique used to assess the performance of a model by 
splitting the data into multiple subsets (folds) and training/testing the model on different combinations of these subsets.
It helps in evaluating the model's generalization ability and in selecting hyperparameters.

'''
# Out:
# "\nCross Validation:\nCross-validation is a technique used to assess the performance of a model by \nsplitting the data into multiple subsets (folds) and training/testing the model on different combinations of these subsets.\nIt helps in evaluating the model's generalization ability and in selecting hyperparameters.\n\n"

# %%
'''
Types of Cross Validation:
1. K-Fold Cross Validation:
K-Fold Cross Validation is a technique where the dataset is divided into K equally sized folds.
Each fold is used as a validation set while the remaining K-1 folds are used for training.
The process is repeated K times, with each fold serving as the validation set once.

2. Stratified K-Fold Cross Validation:
Stratified K-Fold Cross Validation is a variation of K-Fold Cross Validation that ensures each fold has the same proportion of classes as the entire dataset.
This is particularly useful for imbalanced datasets, where some classes may have significantly fewer samples than others

3. Leave-One-Out Cross Validation (LOOCV):
Leave-One-Out Cross Validation is a special case of K-Fold Cross Validation where K is equal to the number of samples in the dataset.
In LOOCV, each sample is used as a validation set once, while the remaining samples are used for training.
This method can be computationally expensive for large datasets but provides an unbiased estimate of the model's performance.

4. Leave-P-Out Cross Validation:
Leave-P-Out Cross Validation is a generalization of LOOCV where P samples are left out for validation, and the remaining samples are used for training.
This method allows for more flexibility in the number of samples used for validation, but it can also be computationally expensive, especially for large datasets.

5. Time Series Cross Validation:
Time Series Cross Validation is a technique specifically designed for time series data.
It involves splitting the data into training and validation sets based on time, ensuring that the validation set always comes after the training set.
This is important for time series data, as the order of observations matters, and future data should not be used to predict past data.


'''
# Out:
# "\nTypes of Cross Validation:\n1. K-Fold Cross Validation:\nK-Fold Cross Validation is a technique where the dataset is divided into K equally sized folds.\nEach fold is used as a validation set while the remaining K-1 folds are used for training.\nThe process is repeated K times, with each fold serving as the validation set once.\n\n2. Stratified K-Fold Cross Validation:\nStratified K-Fold Cross Validation is a variation of K-Fold Cross Validation that ensures each fold has the same proportion of classes as the entire dataset.\nThis is particularly useful for imbalanced datasets, where some classes may have significantly fewer samples than others\n\n3. Leave-One-Out Cross Validation (LOOCV):\nLeave-One-Out Cross Validation is a special case of K-Fold Cross Validation where K is equal to the number of samples in the dataset.\nIn LOOCV, each sample is used as a validation set once, while the remaining samples are used for training.\nThis method can be computationally expensive for lar
# ...

# %% [markdown]
# ## Algerian Forest Fires Dataset

# %%
'''
Algerian Forest Fires Dataset:
The Algerian Forest Fires dataset is a collection of data related to forest fires in Algeria.
It includes various features such as meteorological conditions, geographical information, and fire occurrence.
The dataset is often used for classification tasks to predict the occurrence of forest fires based on these features.
The dataset can be used to train machine learning models to classify whether a fire will occur based on the given features.
'''
# Out:
# '\nAlgerian Forest Fires Dataset:\nThe Algerian Forest Fires dataset is a collection of data related to forest fires in Algeria.\nIt includes various features such as meteorological conditions, geographical information, and fire occurrence.\nThe dataset is often used for classification tasks to predict the occurrence of forest fires based on these features.\nThe dataset can be used to train machine learning models to classify whether a fire will occur based on the given features.\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/abhik12295/Datasets/refs/heads/main/Algerian_forest_fires_dataset_UPDATE.csv', header = 1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# ## Data Cleaning

# %%
# missing values
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
# filter rows with any missing values
# axis=1 means check for missing values across columns
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.iloc[122:] # second datapart in file
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
# 124                             01     06  2012           32   71   12    0.7
# 125                             02     06  2012           30   73   13      4
# 126                             03     06  2012           29   80   14      2
# ..                             ...    ...   ...          ...  ...  ...    ...
# 241                             26     09  2012           30   65   14      0
# 242                             27     09  2012           28   87   15    4.4
# 243                             28     09  2012           27   87   29    0.5
# 244                             29     09  2012           24   54   18    0.1
# 245                             30     09  2012           24   64   15    0.2
#
# ...

# %%
df.iloc[:122]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 117  26    09  2012          31  54  11     0    82    6  16.3  2.5  6.2  1.7
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
#
#        Classes
# 0    not fire
# ...

# %%
'''
So here we have two parts of the dataset, one with 122 rows and another with 244 rows.
so we will make a column assign code as 0 and 1
1. "Bejaia Region"
2. "Sidi Bel Abbes Region"
'''
df.loc[:122, "Region"] = 0  # Bejaia Region
df.loc[122:, "Region"] = 1  # Sidi Bel Abbes Region

# %%
df[df['Region'] == 0].head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df[df['Region']==1].head()
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
# 124                             01     06  2012           32   71   12    0.7
# 125                             02     06  2012           30   73   13      4
# 126                             03     06  2012           29   80   14      2
#
#      FFMC  DMC   DC  ISI  BUI  FWI    Classes    Region
# 122   NaN  NaN  NaN  NaN  NaN  NaN          NaN     1.0
# 123  FFMC  DMC   DC  ISI  BUI  FWI    Classes       1.0
# 124  57.1  2.5  8.2  0.6  2.8  0.2  not fire        1.0
# 125  55.7  2.7  7.8  0.6  2.9  0.2  not fire        1.0
# 126  48.7  2.2  7.6  0.3  2.6  0.1  not fire        1.0

# %%
# drop row 122
df.drop(122,axis=0, inplace=True)

# %%
df[df['Region'] == 1].head()
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 123  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 124   01     06  2012           32   71   12    0.7  57.1  2.5   8.2  0.6
# 125   02     06  2012           30   73   13      4  55.7  2.7   7.8  0.6
# 126   03     06  2012           29   80   14      2  48.7  2.2   7.6  0.3
# 127   04     06  2012           30   64   14      0  79.4  5.2  15.4  2.2
#
#      BUI  FWI    Classes    Region
# 123  BUI  FWI    Classes       1.0
# 124  2.8  0.2  not fire        1.0
# 125  2.9  0.2  not fire        1.0
# 126  2.6  0.1  not fire        1.0
# 127  5.6    1  not fire        1.0

# %%
# also need to drop row 123
df.drop(123, axis=0, inplace=True)

# %%
df[df['Region'] == 1].head()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 124  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 127  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
# 128  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8  6.5  0.9
#
#        Classes    Region
# 124  not fire        1.0
# 125  not fire        1.0
# 126  not fire        1.0
# 127  not fire        1.0
# 128  not fire        1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 30.5+ KB

# %%
df[['Region']] = df[['Region']].astype(int)  # Convert 'Region' column to integer type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 30.5+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df[df.isnull().any(axis=1)]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC   ISI   BUI  \
# 167  14    07  2012          37  37  18   0.2  88.9  12.9  14.6 9  12.5  10.4
#
#          FWI Classes    Region
# 167  fire          NaN       1

# %%
df.dropna(inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  , Region]
# Index: []

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
# fix spaces in column names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 30.4+ KB

# %%
df.head(1)
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# 0    0.5   not fire          0
# ...

# %%
# convert the required columns to numeric
convert_to_int = ['day', 'month', 'year', 'Temperature', 'RH', 'Ws']
convert_to_float = ['Rain','FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']
for col in convert_to_int:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric, coerce errors to NaN

# convert the required columns to float
for col in convert_to_float:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric, coerce errors to NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 30.4+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %% [markdown]
# ## EDA and Feature Engineering

# %%
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv', index=False)

# %%
df1 = df.copy()

# %%
# drop no longer needed columns
# 'day', 'month', 'year' are not needed for the model
df1 = df.drop(columns=['day', 'month', 'year'], axis=1)

# %%
df1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Encoding the 'Classess' column - changing not fire to 0 , else 1
df1['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %%
# if text contains 'not fire' then 0 else 1 using np.where
df1['Classes'] = np.where(df1['Classes'].str.contains('not fire'), 0,1)

# %%
df1['Classes'].unique()
# Out:
# array([0, 1])

# %%
df1['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
# Density plot for all features
plt.style.use('seaborn-v0_8')
df1.hist(figsize=(20, 15), bins=30, density=True)
plt.show()

# %%
# percentage of fire and not fire
fire_percentage = df1['Classes'].value_counts(normalize=True) * 100
print(f"Percentage of Fire: {fire_percentage[1]:.2f}%")
print(f"Percentage of Not Fire: {fire_percentage[0]:.2f}%")
# Out:
# Percentage of Fire: 56.38%
# Percentage of Not Fire: 43.62%

# %%
classLabels = ["Fire", "Not Fire"]
plt.figure(figsize=(8, 6))
plt.pie(fire_percentage, labels=classLabels, autopct='%1.1f%%', startangle=90)
plt.title('Fire vs Not Fire Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is a circle.
plt.show()

# %%
# Correlation matrix
df1.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df1.corr(), annot=True, cmap='hot', fmt='.2f')
# Out:
# <Axes: >

# %%
# FWI as dependent variable
# boxplot for FWI
sns.boxplot(df['FWI'], color='green')
# Out:
# <Axes: ylabel='FWI'>

# %%
# Monthly Fire Analysis
df['Classes'] = np.where(df['Classes'].str.contains('not fire'), 'not fire', 'fire')

# %%
# countplot
dftemp = df.loc[df['Region']==1]
plt.subplots(figsize = (13,6))
sns.set_style("whitegrid")
sns.countplot(x='month', hue='Classes', data=dftemp)
plt.ylabel('Number of Fires')
plt.xlabel('Month')
plt.title('Monthly Fire Analysis in Sidi Bel Abbes Region')
plt.legend(title='Classes')
plt.show()

# %%
# countplot
dftemp = df.loc[df['Region']==0]
plt.subplots(figsize = (13,6))
sns.set_style("whitegrid")
sns.countplot(x='month', hue='Classes', data=dftemp)
plt.ylabel('Number of Fires')
plt.xlabel('Month')
plt.title('Monthly Fire Analysis in Bejaia Region')
plt.legend(title='Classes')
plt.show()

# %%
'''
Observations:
- The dataset contains two regions: Bejaia and Sidi Bel Abbes.
- The 'Classes' column has been encoded to represent fire (1) and not fire (0).
- Countplots show the distribution of fires across months in both regions, 
where Sidi Bel Abbes has a higher number of fires in the summer months (June, July, August) compared to Bejaia.
- August and september have the highest number of fires in both regions, indicating a seasonal pattern.
- less fires in September for both regions, which could be due to the end of the summer season and reduced fire risk.
'''

# %%
'''
Feature Selection:
Model Training:
'''

# %%
df = pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv')
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.drop(['day','month','year'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Encoding
df['Classes'] = np.where(df['Classes'].str.contains('not fire'), 0, 1)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
# independent and dependent variables
X = df.drop('FWI', axis = 1)
y = df['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((182, 11), (61, 11), (182,), (61,))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
# check for multicollinearity
plt.figure(figsize=(12, 10))
sns.heatmap(X_train.corr(), annot=True, cmap='hot', fmt='.2f')
# Out:
# <Axes: >
